# %%
# !git clone https://github.com/A2022KR/strategic-planning-resilience-egypt.git
# %cd strategic-planning-resilience-egypt
# !ls

# %%
# %cd /content/strategic-planning-resilience-egypt
# !mkdir -p data outputs scripts notebooks
# !ls -la

# %%
# %%bash
# cp -r /content/data/* /content/strategic-planning-resilience-egypt/data/ 2>/dev/null || true
# cp -r /content/outputs/* /content/strategic-planning-resilience-egypt/outputs/ 2>/dev/null || true
# cp -r /content/scripts/* /content/strategic-planning-resilience-egypt/scripts/ 2>/dev/null || true
# cp /content/requirements.txt /content/strategic-planning-resilience-egypt/ 2>/dev/null || true

# %%
# !find . -maxdepth 2 -type f | sort

# %%
# !ls -la /content

# %%
# !unzip -o /content/replication_package.zip -d /content/rep_pkg
# !find /content/rep_pkg -maxdepth 2 -type f | sort

# %%
# !cp -r /content/rep_pkg/data/* /content/strategic-planning-resilience-egypt/data/
# !cp -r /content/rep_pkg/outputs/* /content/strategic-planning-resilience-egypt/outputs/
# !cp -r /content/rep_pkg/scripts/* /content/strategic-planning-resilience-egypt/scripts/
# !cp /content/rep_pkg/requirements.txt /content/strategic-planning-resilience-egypt/

# %%
# %cd /content/strategic-planning-resilience-egypt
# !find . -maxdepth 2 -type f | sort

# %%
import glob, os, pandas as pd

paths = glob.glob("/content/drive/MyDrive/**/*.ipynb", recursive=True)
print("Total .ipynb found in Drive:", len(paths))

df = pd.DataFrame({"path": paths, "mtime": [os.path.getmtime(p) for p in paths]})
df = df.sort_values("mtime", ascending=False)
df.head(15)
# Out:
# Total .ipynb found in Drive: 44
#                                                  path         mtime
# 43  /content/drive/MyDrive/Colab Notebooks/Replica...  1.769439e+09
# 42  /content/drive/MyDrive/Colab Notebooks/Copy of...  1.769439e+09
# 41  /content/drive/MyDrive/Colab Notebooks/Replica...  1.769433e+09
# 40  /content/drive/MyDrive/Colab Notebooks/Strateg...  1.769432e+09
# 39  /content/drive/MyDrive/Colab Notebooks/Concept...  1.769198e+09
# 38  /content/drive/MyDrive/Colab Notebooks/Untitle...  1.760014e+09
# 37  /content/drive/MyDrive/Colab Notebooks/Untitle...  1.759997e+09
# 36  /content/drive/MyDrive/Colab Notebooks/Untitle...  1.759786e+09
# 35  /content/drive/MyDrive/Colab Notebooks/Untitle...  1.759782e+09
# 34  /content/drive/MyDrive/Colab Notebooks/Untitle...  1.759691e+09
# 33  /content/drive/MyDrive/Colab Notebooks/Untitle...  1.759586e+09
# 1               /content/drive/MyDrive/EC_EP_FP.ipynb  1.759351e+09
# ...
